# %%
import random

random.seed("USTC")
keys = ["yuqing", "luankang", "qiushi"]
values = random.sample([1, 2, 3], 3)  
result_dict = dict(zip(keys, values))  

print("result:", result_dict)
# Out:
# result: {'yuqing': 2, 'luankang': 1, 'qiushi': 3}

# %%
import json
import matplotlib.pyplot as plt
import math
import numpy as np

# %%
colors = ['#66BC98', '#AAD09D', '#E3EA96', '#FCDC89', '#E26844', '#8A233F', '#C2ABC8']
colors = ['#66BC98', '#AAD09D', '#E3EA96', '#FCDC89', '#E26844', '#8A233F', '#C2ABC8']
colors = ["#89c8e8","#caa2f4","#1f78b4","#6a3d9a","#8acc72", "#ebd57c", "#ed4437", "#fc9a9a"]
tag = ['Zip', 'Random', 'Cluster', 'Perplexity', 'Deita', 'SuperFiltering']

# %% [markdown]
# # K1

# %%
x = ['200', '1000', '10000', '20000']
y = [7.13, 7.17, 7.285, 7.12]
y2 = [6.92, 7.07, 7.09, 6.91]

# Plot the fitting curve
plt.plot(x, y, color=colors[2], label="Llama-3-8B", linestyle='-', marker='o',)
plt.plot(x, y2, color=colors[7], label="Mistral-7B", linestyle='--', marker='s',)

ax = plt.gca()
ax.set_ylim([6.85, 7.35])

# Add legend
plt.legend()

# Add title and axis labels
plt.ylabel('Model performance')

# Display the plot
plt.savefig(f"/zhdd/home/mjyin/Projects/axolotl/figure/hyper/llama3_k1.pdf", format='pdf', dpi=1000, bbox_inches='tight', transparent=True)
plt.show()

# %%
x = ['100', '200', '500', '1000']
y = [7.15, 7.285, 7.281, 7.25]
y2 = [6.95, 7.08, 7.04, 7.06]

# Plot the fitting curve
plt.plot(x, y, color=colors[2], label="Llama-3-8B", linestyle='-', marker='o',)
plt.plot(x, y2, color=colors[7], label="Mistral-7B", linestyle='--', marker='s',)

ax = plt.gca()
ax.set_ylim([6.85, 7.35])

# Add legend
plt.legend()

# Add title and axis labels
plt.ylabel('Model performance')

# Display the plot
plt.savefig(f"/zhdd/home/mjyin/Projects/axolotl/figure/hyper/llama3_k2.pdf", format='pdf', dpi=1000, bbox_inches='tight', transparent=True)
plt.show()

# %%
x = ['50', '100', '150', '200']
y = [7.11, 7.285, 7.18, 7.13]
y2 = [7.11, 7.08, 7.20, 7.09]

# Plot the fitting curve
plt.plot(x, y, color=colors[2], label="Llama-3-8B", linestyle='-', marker='o',)
plt.plot(x, y2, color=colors[7], label="Mistral-7B", linestyle='--', marker='s',)

ax = plt.gca()
ax.set_ylim([7.00, 7.35])

# Add legend
plt.legend()

# Add title and axis labels
plt.ylabel('Model performance')

# Display the plot
plt.savefig(f"/zhdd/home/mjyin/Projects/axolotl/figure/hyper/llama3_k3.pdf", format='pdf', dpi=1000, bbox_inches='tight', transparent=True)
plt.show()
