# %%
import json
import matplotlib.pyplot as plt
import math
import numpy as np

# %%
colors = ['#66BC98', '#AAD09D', '#E3EA96', '#FCDC89', '#E26844', '#8A233F', '#C2ABC8']
colors = ['#66BC98', '#AAD09D', '#E3EA96', '#FCDC89', '#E26844', '#8A233F', '#C2ABC8']
colors = ["#89c8e8","#caa2f4","#1f78b4","#6a3d9a","#8acc72", "#ebd57c", "#ed4437", "#fc9a9a"]
tag = ['Zip', 'Random', 'Cluster', 'Perplexity', 'Deita', 'SuperFiltering']

# %% [markdown]
# # K1

# %%
x = ['200', '1000', '10000', '20000']
y = [6.92, 7.07, 7.09, 6.91]

# Plot the fitting curve
plt.plot(x, y, color=colors[2])

ax = plt.gca()
ax.set_ylim([6.80, 7.25])

# Add legend
plt.legend()

# Add title and axis labels
plt.ylabel('Model performance')

# Display the plot
plt.savefig(f"/zhdd/home/mjyin/Projects/axolotl/figure/hyper/mistral_k1.pdf", format='pdf', dpi=1000, bbox_inches='tight', transparent=True)
plt.show()
# Out:
# /tmp/ipykernel_3348596/3577483474.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
x = ['100', '200', '500', '1000']
y = [6.95, 7.08, 7.04, 7.06]

# Plot the fitting curve
plt.plot(x, y, color=colors[2])

ax = plt.gca()
ax.set_ylim([6.85, 7.20])

# Add legend
plt.legend()

# Add title and axis labels
plt.ylabel('Model performance')

# Display the plot
plt.savefig(f"/zhdd/home/mjyin/Projects/axolotl/figure/hyper/mistral_k2.pdf", format='pdf', dpi=1000, bbox_inches='tight', transparent=True)
plt.show()
# Out:
# /tmp/ipykernel_3348596/1109845155.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
x = ['50', '100', '150', '200']
y = [7.11, 7.08, 7.20, 7.09]

# Plot the fitting curve
plt.plot(x, y, color=colors[2])

ax = plt.gca()
ax.set_ylim([7.00, 7.30])

# Add legend
plt.legend()

# Add title and axis labels
plt.ylabel('Model performance')

# Display the plot
plt.savefig(f"/zhdd/home/mjyin/Projects/axolotl/figure/hyper/mistral_k3.pdf", format='pdf', dpi=1000, bbox_inches='tight', transparent=True)
plt.show()
# Out:
# /tmp/ipykernel_3348596/3933166906.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
